# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('E0.csv')

# %%
df
# Out:
#     Div        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0    E0  05/08/2022  20:00  Crystal Palace        Arsenal     0     2   A
# 1    E0  06/08/2022  12:30          Fulham      Liverpool     2     2   D
# 2    E0  06/08/2022  15:00     Bournemouth    Aston Villa     2     0   H
# 3    E0  06/08/2022  15:00           Leeds         Wolves     2     1   H
# 4    E0  06/08/2022  15:00       Newcastle  Nott'm Forest     2     0   H
# ..   ..         ...    ...             ...            ...   ...   ...  ..
# 246  E0  04/03/2023  15:00          Wolves      Tottenham     1     0   H
# 247  E0  04/03/2023  17:30     Southampton      Leicester     1     0   H
# 248  E0  05/03/2023  14:00   Nott'm Forest        Everton     2     2   D
# 249  E0  05/03/2023  16:30       Liverpool     Man United     7     0   H
# 250  E0  06/03/2023  20:00       Brentford         Fulham     3     2   H
#
#      HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  \
# ...

# %%
df = df[['HomeTeam','AwayTeam','FTR','B365H', 'B365D', 'B365A']]

# %%
df
# Out:
#            HomeTeam       AwayTeam FTR  B365H  B365D  B365A
# 0    Crystal Palace        Arsenal   A   4.20    3.6   1.85
# 1            Fulham      Liverpool   D  11.00    6.0   1.25
# 2       Bournemouth    Aston Villa   H   3.75    3.5   2.00
# 3             Leeds         Wolves   H   2.25    3.4   3.20
# 4         Newcastle  Nott'm Forest   H   1.66    3.8   5.25
# ..              ...            ...  ..    ...    ...    ...
# 246          Wolves      Tottenham   H   3.30    3.4   2.20
# 247     Southampton      Leicester   H   2.75    3.3   2.60
# 248   Nott'm Forest        Everton   D   2.70    3.0   2.88
# 249       Liverpool     Man United   H   2.38    3.6   2.88
# 250       Brentford         Fulham   H   1.95    3.6   3.75
#
# [251 rows x 6 columns]

# %%
df['New'] = df.apply(lambda x: x['B365H'] if x['B365H'] < x['B365A'] else 'underdog', axis=1)
# Out:
# C:\Users\hask777\AppData\Local\Temp\ipykernel_3920\8427602.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['New'] = df.apply(lambda x: x['B365H'] if x['B365H'] < x['B365A'] else 'underdog', axis=1)

# %%
df.tail(50)
# Out:
#            HomeTeam        AwayTeam FTR  B365H  B365D  B365A       New
# 201     Aston Villa       Leicester   A   1.95   3.60   3.80      1.95
# 202       Brentford     Southampton   H   1.85   3.60   4.20      1.85
# 203        Brighton     Bournemouth   H   1.33   5.25   8.50      1.33
# 204      Man United  Crystal Palace   H   1.40   4.75   8.00       1.4
# 205          Wolves       Liverpool   H   4.00   3.80   1.85  underdog
# 206       Newcastle        West Ham   D   1.60   3.80   6.00       1.6
# 207   Nott'm Forest           Leeds   H   2.63   3.30   2.70      2.63
# 208       Tottenham        Man City   H   4.33   4.20   1.73  underdog
# 209      Man United           Leeds   D   1.45   5.00   6.00      1.45
# 210        West Ham         Chelsea   D   3.30   3.30   2.25  underdog
# 211         Arsenal       Brentford   D   1.44   4.75   7.00      1.44
# 212  Crystal Palace        Brighton   D   3.80   3.50   2.00  underdog
# ...

# %%
un_h = df.copy()

# %%
un_h = un_h.loc[(un_h['New'] == 'underdog') & (un_h['FTR'] == 'H')]

# %%
"""
Домашний андердог победил
"""

un_h
# Out:
#           HomeTeam        AwayTeam FTR  B365H  B365D  B365A       New
# 2      Bournemouth     Aston Villa   H   3.75   3.50   2.00  underdog
# 16       Brentford      Man United   H   3.75   3.50   2.00  underdog
# 17   Nott'm Forest        West Ham   H   4.20   3.60   1.85  underdog
# 26           Leeds         Chelsea   H   5.75   4.50   1.53  underdog
# 29      Man United       Liverpool   H   5.25   4.33   1.60  underdog
# 41          Fulham        Brighton   H   3.10   3.30   2.30  underdog
# 42     Southampton         Chelsea   H   5.25   4.00   1.61  underdog
# 66         Everton        West Ham   H   2.90   3.25   2.50  underdog
# 77     Bournemouth       Leicester   H   3.60   3.40   2.05  underdog
# 87       Brentford        Brighton   H   3.10   3.40   2.30  underdog
# 96       Liverpool        Man City   H   3.60   4.00   1.90  underdog
# 104         Fulham     Aston Villa   H   2.90   3.30   2.50  underdog
# ...

# %%
un_h.shape[0]
# Out:
# 28

# %%
uhs = un_h['B365H'].sum()

# %%
uhs
# Out:
# 115.73

# %%
un_a = df.copy()

# %%
un_a = un_a.loc[(un_a['New'] == 'underdog') & (un_a['FTR'] == 'A')]

# %%
"""
Домашний андердог проиграл
"""

un_a
# Out:
#            HomeTeam        AwayTeam FTR  B365H  B365D  B365A       New
# 0    Crystal Palace         Arsenal   A   4.20   3.60   1.85  underdog
# 6           Everton         Chelsea   A   5.50   4.00   1.61  underdog
# 9          West Ham        Man City   A   8.00   5.00   1.36  underdog
# 25      Bournemouth         Arsenal   A   8.00   4.75   1.40  underdog
# 30      Southampton      Man United   A   4.20   4.00   1.80  underdog
# 39    Nott'm Forest       Tottenham   A   7.00   4.60   1.44  underdog
# 49        Leicester      Man United   A   3.40   3.75   2.05  underdog
# 61    Nott'm Forest          Fulham   A   2.75   3.30   2.62  underdog
# 62           Wolves        Man City   A   9.50   5.00   1.33  underdog
# 65        Brentford         Arsenal   A   4.20   3.80   1.80  underdog
# 69   Crystal Palace         Chelsea   A   4.20   3.60   1.85  underdog
# 70           Fulham       Newcastle   A   3.00   3.40   2.37  underdog
# ...

# %%
un_a.shape[0]
# Out:
# 43

# %%
uha = un_a['B365H'].sum()

# %%
uha
# Out:
# 199.68

# %%
un_d = df.copy()

# %%
un_d = un_d.loc[(un_d['New'] == 'underdog') & (un_d['FTR'] == 'D')]

# %%
un_d
# Out:
#            HomeTeam       AwayTeam FTR  B365H  B365D  B365A       New
# 1            Fulham      Liverpool   D  11.00   6.00   1.25  underdog
# 28        Newcastle       Man City   D   7.50   5.00   1.36  underdog
# 38           Wolves      Newcastle   D   2.70   3.30   2.70  underdog
# 45      Bournemouth         Wolves   D   3.50   3.30   2.15  underdog
# 47         West Ham      Tottenham   D   3.60   3.80   1.95  underdog
# 50          Everton      Liverpool   D   7.00   4.75   1.40  underdog
# 57      Aston Villa       Man City   D   8.00   5.50   1.33  underdog
# 68      Bournemouth      Brentford   D   3.30   3.40   2.20  underdog
# 86    Nott'm Forest    Aston Villa   D   3.30   3.40   2.20  underdog
# 95      Southampton       West Ham   D   2.90   3.40   2.40  underdog
# 100       Brentford        Chelsea   D   4.75   3.80   1.72  underdog
# 112     Southampton        Arsenal   D   6.00   4.00   1.57  underdog
# ...

# %%
un_d.shape[0]
# Out:
# 25

# %%
dif =  (251-42-28-22)

# %%
dif
# Out:
# 159
