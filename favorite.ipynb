# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('E0.csv')

# %%
df
# Out:
#     Div        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0    E0  05/08/2022  20:00  Crystal Palace        Arsenal     0     2   A
# 1    E0  06/08/2022  12:30          Fulham      Liverpool     2     2   D
# 2    E0  06/08/2022  15:00     Bournemouth    Aston Villa     2     0   H
# 3    E0  06/08/2022  15:00           Leeds         Wolves     2     1   H
# 4    E0  06/08/2022  15:00       Newcastle  Nott'm Forest     2     0   H
# ..   ..         ...    ...             ...            ...   ...   ...  ..
# 246  E0  04/03/2023  15:00          Wolves      Tottenham     1     0   H
# 247  E0  04/03/2023  17:30     Southampton      Leicester     1     0   H
# 248  E0  05/03/2023  14:00   Nott'm Forest        Everton     2     2   D
# 249  E0  05/03/2023  16:30       Liverpool     Man United     7     0   H
# 250  E0  06/03/2023  20:00       Brentford         Fulham     3     2   H
#
#      HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  \
# ...

# %%
df = df[['HomeTeam','AwayTeam','FTR','B365H', 'B365D', 'B365A']]

# %%
df
# Out:
#            HomeTeam       AwayTeam FTR  B365H  B365D  B365A
# 0    Crystal Palace        Arsenal   A   4.20    3.6   1.85
# 1            Fulham      Liverpool   D  11.00    6.0   1.25
# 2       Bournemouth    Aston Villa   H   3.75    3.5   2.00
# 3             Leeds         Wolves   H   2.25    3.4   3.20
# 4         Newcastle  Nott'm Forest   H   1.66    3.8   5.25
# ..              ...            ...  ..    ...    ...    ...
# 246          Wolves      Tottenham   H   3.30    3.4   2.20
# 247     Southampton      Leicester   H   2.75    3.3   2.60
# 248   Nott'm Forest        Everton   D   2.70    3.0   2.88
# 249       Liverpool     Man United   H   2.38    3.6   2.88
# 250       Brentford         Fulham   H   1.95    3.6   3.75
#
# [251 rows x 6 columns]

# %%
df['New'] = df.apply(lambda x: x['B365H'] if x['B365H'] <= x['B365A'] else 'underdog', axis=1)
# Out:
# C:\Users\hask777\AppData\Local\Temp\ipykernel_1568\1489576516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['New'] = df.apply(lambda x: x['B365H'] if x['B365H'] <= x['B365A'] else 'underdog', axis=1)

# %%
df
# Out:
#            HomeTeam       AwayTeam FTR  B365H  B365D  B365A       New
# 0    Crystal Palace        Arsenal   A   4.20    3.6   1.85  underdog
# 1            Fulham      Liverpool   D  11.00    6.0   1.25  underdog
# 2       Bournemouth    Aston Villa   H   3.75    3.5   2.00  underdog
# 3             Leeds         Wolves   H   2.25    3.4   3.20      2.25
# 4         Newcastle  Nott'm Forest   H   1.66    3.8   5.25      1.66
# ..              ...            ...  ..    ...    ...    ...       ...
# 246          Wolves      Tottenham   H   3.30    3.4   2.20  underdog
# 247     Southampton      Leicester   H   2.75    3.3   2.60  underdog
# 248   Nott'm Forest        Everton   D   2.70    3.0   2.88       2.7
# 249       Liverpool     Man United   H   2.38    3.6   2.88      2.38
# 250       Brentford         Fulham   H   1.95    3.6   3.75      1.95
#
# [251 rows x 7 columns]

# %%
fa_h = df.copy()

# %%
fa_h = fa_h.loc[(fa_h['New'] != 'underdog') & (fa_h['FTR'] == 'H')]

# %%
fa_h
# Out:
#         HomeTeam        AwayTeam FTR  B365H  B365D  B365A   New
# 3          Leeds          Wolves   H   2.25   3.40   3.20  2.25
# 4      Newcastle   Nott'm Forest   H   1.66   3.80   5.25  1.66
# 5      Tottenham     Southampton   H   1.33   5.50   8.50  1.33
# 10   Aston Villa         Everton   H   1.80   3.50   4.75   1.8
# 11       Arsenal       Leicester   H   1.53   4.33   5.75  1.53
# ..           ...             ...  ..    ...    ...    ...   ...
# 243  Aston Villa  Crystal Palace   H   2.05   3.30   3.80  2.05
# 244     Brighton        West Ham   H   1.80   3.60   4.50   1.8
# 245      Chelsea           Leeds   H   1.62   4.00   5.50  1.62
# 249    Liverpool      Man United   H   2.38   3.60   2.88  2.38
# 250    Brentford          Fulham   H   1.95   3.60   3.75  1.95
#
# [92 rows x 7 columns]

# %%
fas = fa_h['B365H'].sum()

# %%
fas
# Out:
# 158.17000000000002

# %%
fa_a = df.copy()

# %%
fa_a = fa_a.loc[(fa_a['New'] != 'underdog') & (fa_a['FTR'] == 'A')]

# %%
fa_a
# Out:
#            HomeTeam        AwayTeam FTR  B365H  B365D  B365A   New
# 8        Man United        Brighton   A   1.60   4.20   5.25   1.6
# 24        Leicester     Southampton   A   1.83   4.00   4.00  1.83
# 27         West Ham        Brighton   A   2.30   3.40   3.10   2.3
# 37      Aston Villa        West Ham   A   2.30   3.40   3.10   2.3
# 54    Nott'm Forest     Bournemouth   A   1.95   3.50   3.80  1.95
# 72      Southampton         Everton   A   2.15   3.40   3.40  2.15
# 99      Bournemouth     Southampton   A   2.62   3.30   2.62  2.62
# 111           Leeds          Fulham   A   2.05   3.50   3.60  2.05
# 113          Wolves       Leicester   A   2.25   3.25   3.25  2.25
# 114       Tottenham       Newcastle   A   2.05   3.50   3.50  2.05
# 123       Liverpool           Leeds   A   1.30   6.00   9.00   1.3
# 130         Everton       Leicester   A   2.40   3.30   3.00   2.4
# 131         Chelsea         Arsenal   A   2.55   3.40   2.70  2.55
# ...

# %%
fas = fa_a['B365H'].sum()

# %%
fas
# Out:
# 60.41

# %%
fa_d = df.copy()

# %%
fa_d = fa_d.loc[(fa_d['New'] != 'underdog') & (fa_d['FTR'] == 'D')]

# %%
fa_d
# Out:
#            HomeTeam        AwayTeam FTR  B365H  B365D  B365A   New
# 7         Leicester       Brentford   D   2.00   3.75   3.50   2.0
# 12         Brighton       Newcastle   D   2.45   3.20   3.00  2.45
# 14      Southampton           Leeds   D   2.25   3.50   3.10  2.25
# 15           Wolves          Fulham   D   2.30   3.30   3.20   2.3
# 18          Chelsea       Tottenham   D   2.25   3.40   3.20  2.25
# 19        Liverpool  Crystal Palace   D   1.18   6.75  16.00  1.18
# 22          Everton   Nott'm Forest   D   1.90   3.60   4.00   1.9
# 31        Brentford         Everton   D   2.00   3.50   3.75   2.0
# 38           Wolves       Newcastle   D   2.70   3.30   2.70   2.7
# 40   Crystal Palace       Brentford   D   2.05   3.40   3.60  2.05
# 43            Leeds         Everton   D   2.15   3.50   3.30  2.15
# 53        Newcastle  Crystal Palace   D   2.00   3.50   3.75   2.0
# 63        Newcastle     Bournemouth   D   1.44   4.40   7.50  1.44
# ...

# %%
fad = fa_d['B365D'].sum()

# %%
fad
# Out:
# 145.85
